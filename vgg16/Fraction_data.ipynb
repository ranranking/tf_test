# %%
import numpy as np
import pandas as pd

# %%
full_train = pd.read_csv('./new_train_full.txt', delimiter=' ', header=None)

frac_train = pd.DataFrame()

for i in full_train[1].unique():
    frac = full_train.loc[full_train[1] == i].sample(frac=0.1)
    frac_train = frac_train.append(frac, ignore_index=True)

# %%
frac_train
# Out:
#                                                      0   1
# 0       /home/zhmiao/New_Set/Civet/part_2_04170696.JPG   0
# 1       /home/zhmiao/New_Set/Civet/part_5_EK006899.JPG   0
# 2       /home/zhmiao/New_Set/Civet/part_5_EK006166.JPG   0
# 3       /home/zhmiao/New_Set/Civet/part_5_EK006896.JPG   0
# 4       /home/zhmiao/New_Set/Civet/part_5_02270485.JPG   0
# 5       /home/zhmiao/New_Set/Civet/part_5_EK007508.JPG   0
# 6       /home/zhmiao/New_Set/Civet/part_5_11210174.JPG   0
# 7       /home/zhmiao/New_Set/Civet/part_2_05200429.JPG   0
# 8       /home/zhmiao/New_Set/Civet/part_4_EK001255.JPG   0
# 9       /home/zhmiao/New_Set/Civet/part_5_EK008130.JPG   0
# 10      /home/zhmiao/New_Set/Civet/part_5_EK000150.JPG   0
# 11      /home/zhmiao/New_Set/Civet/part_3_05220371.JPG   0
# 12      /home/zhmiao/New_Set/Civet/part_5_EK000015.JPG   0
# 13      /home/zhmiao/New_Set/Civet/part_5_EK008353.JPG   0
# 14      /home/zhmiao/New_Set/Civet/part_5_01180623.JPG   0
# ...
